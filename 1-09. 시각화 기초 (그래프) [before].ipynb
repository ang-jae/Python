# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data = np.random.randn(50).cumsum()
print(data)
plt.plot(data)
plt.show()
# Out:
# [-1.24607285 -0.39948178  0.72051539  1.32118028  2.47787245  3.01647742
#   4.51364235  4.8898514   3.18100831  3.04136582  4.48455078  3.66393
#   4.07055006  3.52734938  2.7423673   2.1241862   0.58141219  0.79105823
#  -0.39756314 -1.84859567 -2.15384542 -1.26307427 -1.65465251 -1.70704841
#  -1.17699295 -1.65659011 -0.15159194 -0.56914805 -0.75419691 -1.43939636
#  -0.74623051 -2.82682493 -2.5843277  -2.96721335 -2.22606919 -1.50853467
#  -1.19046589 -0.97204459 -1.01916003 -0.32896183 -0.34604131 -0.50064421
#  -2.0642991  -1.16328989  0.86691805  2.65384491  3.0682357   3.09631512
#   3.78672589  2.94170093]

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 2)
plt.subplot(3, 2, 3)
plt.subplot(3, 2, 4)
plt.subplot(3, 2, 5)
plt.subplot(3, 2, 6)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
plt.subplot(2, 2, 1)
plt.plot(data)

plt.subplot(2, 2, 2)
plt.hist(hist_data, bins=20)

plt.subplot(2, 2, 3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))

plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
plt.plot(data, 'yv')
plt.show()

# %%
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(10, 5))
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize=(10, 10)) # 꼭 맨 위에 있어야 한다
plt.subplot(2, 2, 1)
plt.plot(data)

plt.subplot(2, 2, 2)
plt.hist(hist_data, bins=20)

plt.subplot(2, 2, 3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))

plt.show()

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label = 'Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Random Graph')
plt.xlabel('Stages')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.title('Graph')
plt.plot(np.random.randn(1000).cumsum(), 'k^', label='one')
plt.plot(np.random.randn(1000).cumsum(), 'b', label='two')
plt.plot(np.random.randn(1000).cumsum(), 'r', label='three')

plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig('saved_graph.png')
